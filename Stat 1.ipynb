# %%
from PIL import Image
img=Image.open('stat1')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=539x485 at 0xE31430>

# %%
img=Image.open('stat2.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=592x485 at 0x4AA3F90>

# %%
img=Image.open('stat3.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=705x513 at 0x4AA3CD0>

# %%
img=Image.open('stat4.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=677x281 at 0xE317F0>
